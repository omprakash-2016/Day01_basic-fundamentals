# %%
continuation with string data type:

# %%
Introduction to String Methods:
These are built in formulas

# %%
name="om"
print(name)
# Out:
# om

# %%
#ref want to know what kind of data type it is

# %%
type(name)
# Out:
# str

# %%
# str-->string data type

# %%
name2="nandhu"
print(name2)
type(name2)
# Out:
# nandhu
# str

# %%
firstname="thallapally omprakash"
print(firstname)
# Out:
# thallapally omprakash

# %%
print(firstname.title())
# Out:
# Thallapally Omprakash

# %%
#want fullname in captial letters

# %%
print(firstname.upper())
# Out:
# THALLAPALLY OMPRAKASH

# %%
#want fullname in small letters

# %%
print(firstname.lower())
# Out:
# thallapally omprakash

# %%
Adding whitespaces to the strings:

# %%
#req :conducted survey to select the fav programming language

# %%
print("fav_programming : PythonCjavaC++swiftCobal")
# Out:
# fav_programming : PythonCjavaC++swiftCobal

# %%
print("fav_programming : Python\nC\njava\nC++\nswift\nCobal") #\n-->new line delimiter
# Out:
# fav_programming : Python
# C
# java
# C++
# swift
# Cobal

# %%
print("fav_programming : Python\n\tC\n\tjava\n\tC++\n\tswift\n\tCobal") #\t-->new tab delimiter
# Out:
# fav_programming : Python
# 	C
# 	java
# 	C++
# 	swift
# 	Cobal

# %%
print("fav_programming : Python\t\nC\n\tjava\n\tC++\n\tswift\n\tCobal")
# Out:
# fav_programming : Python
# C
# 	java
# 	C++
# 	swift
# 	Cobal
