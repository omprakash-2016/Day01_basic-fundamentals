# %%
print("hello all welcome to the python programming world!")
# Out:
# hello all welcome to the python programming world!

# %%
print("Today is the my first class into the practical implemantation of python programming")
# Out:
# Today is the my first class into the practical implemantation of python programing

# %%
print("Succesfully installed softwares related to python programming as guided by Fayaz sir! ")
# Out:
# Succesfully installed softwares related to python programming as guided by Fayaz sir!
