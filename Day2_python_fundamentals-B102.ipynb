# %%
Introduction to python programming

# %%
Variables:

Variables are the building blocks of the code

# %%
a=2
b=3
c=a+b
print(c)
# Out:
# 5

# %%
Rules for declaring variables:

# %%
1: No namespaces for declaring the variable

first name="om"
print(first name)
# Out:
#   Cell In[4], line 1
#     1: No namespaces for declaring the variable
#     ^
# SyntaxError: illegal target for annotation

# %%
firstname="om"
print(firstname)
# Out:
# om

# %%
2: A variable name should not start with a number **

1name="om"
print(1name)
# Out:
#   Cell In[6], line 3
#     1name="om"
#     ^
# SyntaxError: invalid decimal literal

# %%
name1="om"
print(name1)
# Out:
# om

# %%
3: A variable name should not contain any special characters @,#,$,%,*...
name@="om"
print(name@)
# Out:
#   Cell In[8], line 1
#     3: A variable name should not contain any special characters @,#,$,%,*...
#     ^
# SyntaxError: illegal target for annotation

# %%
INTRODUCTION TO DATA TYPES:

# %%
Strings---->str
Numbers---->integers(int)&float(deciamls 0.1,0.2)
List---->list[]
Tuples--->tuple()
Dictionaries--->dict

# %%
NOTE:Python is a case sensitive programming language
name="om"
#NAME="om"
#Name="om"
print(name)
# Out:
#   Cell In[15], line 1
#     NOTE:Python is a case sensitive programming language
#                      ^
# SyntaxError: invalid syntax

# %%
name="om"
NAME="om"
#Name="om"
print(name)
# Out:
# om

# %%
name="om"
NAME="om"
print(NAME)
# Out:
# om

# %%
Classification of Data Types:
    1:Mutuable --->can edit/alter-->flexible in nature
    2:Immutable--->which can't be able to edit-->fixed in nature

# %%
Introduction to string Data type:

# %%
A string is nothing but series of characters declared in quotes.
Classification : It is calssified as "Immutable data type"
String can be declared in two approches

# %%
1:Single Quote,2:Double Quote

# %%
Name='om'
print(Name)
# Out:
# om

# %%
Name="om"
print(Name)
# Out:
# om
